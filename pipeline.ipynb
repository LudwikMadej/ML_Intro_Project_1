# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("depression_data.csv")

# %%
data.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# 2          Employed  125332.79                 Low      Unhealthy
# 3        Unemployed    9992.78            Moderate       Moderate
# 4        Unemployed    8595.08                 Low       Moderate
#
#   Sleep Patterns History of Mental Illness History of Substance Abuse  \
# 0           Fair                       Yes                         No
# 1           Fair                       Yes                         No
# 2           Good                        No                         No
# 3           Poor                        No                         No
# 4           Fair                       Yes                         No
#
#   Family History of Depression Chronic Medical Conditions
# 0                          Yes                        Yes
# 1                           No                        Yes
# 2                          Yes                         No
# 3                           No                         No
# 4                          Yes                        Yes

# %%
df = data

# %%
df["Marital Status"] = np.where(
        df["Marital Status"] == "Divorced", 0,
        np.where(df["Marital Status"] == "Divorced", 1, 
                np.where(df["Marital Status"] == "Single", 2, 3
                        )
                )
    )

# %%
data["Education Level"].value_counts()
# Out:
# Education Level
# Bachelor's Degree    124329
# High School          118927
# Associate Degree      79999
# Master's Degree       73768
# PhD                   16745
# Name: count, dtype: int64

# %%
df["Education Level"] = np.where(
    df["Education Level"] == "High School", 0,
    np.where(df["Education Level"] == "Accociate Degree", 1, 
             np.where(df["Education Level"] == "Bachelor's Degree", 2,
                      np.where(df["Education Level"] == "Master's Degree", 3,
                               4
                              )
                     )
            )
)

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#   Smoking Status Physical Activity Level Employment Status     Income  \
# 0     Non-smoker                  Active        Unemployed   26265.67
# 1     Non-smoker               Sedentary          Employed   42710.36
# 2     Non-smoker               Sedentary          Employed  125332.79
# 3     Non-smoker                Moderate        Unemployed    9992.78
# 4     Non-smoker               Sedentary        Unemployed    8595.08
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
# 2                 Low      Unhealthy           Good                        No
# 3            Moderate       Moderate           Poor                        No
# 4                 Low       Moderate           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
# 2                         No                          Yes
# 3                         No                           No
# 4                         No                          Yes
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes
# 2                         No
# 3                         No
# 4                        Yes

# %%
df["Smoking Status"].value_counts()
# Out:
# Smoking Status
# Non-smoker    247416
# Former        116184
# Current        50168
# Name: count, dtype: int64

# %%
df["Smoking Status"] = np.where(
    df["Smoking Status"] == "Non-smoker", 0,
        np.where(df["Smoking Status"] == "Former", 1,
                2
        )
)

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#    Smoking Status Physical Activity Level Employment Status     Income  \
# 0               0                  Active        Unemployed   26265.67
# 1               0               Sedentary          Employed   42710.36
# 2               0               Sedentary          Employed  125332.79
# 3               0                Moderate        Unemployed    9992.78
# 4               0               Sedentary        Unemployed    8595.08
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
# 2                 Low      Unhealthy           Good                        No
# 3            Moderate       Moderate           Poor                        No
# 4                 Low       Moderate           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
# 2                         No                          Yes
# 3                         No                           No
# 4                         No                          Yes
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes
# 2                         No
# 3                         No
# 4                        Yes

# %%
df["Physical Activity Level"] = np.where(
    df["Physical Activity Level"] == "Sedentary", 0, 
    np.where(df["Physical Activity Level"] == "Moderate", 1,
            2
        )
    )

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#    Smoking Status  Physical Activity Level Employment Status     Income  \
# 0               0                        2        Unemployed   26265.67
# 1               0                        0          Employed   42710.36
# 2               0                        0          Employed  125332.79
# 3               0                        1        Unemployed    9992.78
# 4               0                        0        Unemployed    8595.08
#
#   Alcohol Consumption Dietary Habits Sleep Patterns History of Mental Illness  \
# 0            Moderate       Moderate           Fair                       Yes
# 1                High      Unhealthy           Fair                       Yes
# 2                 Low      Unhealthy           Good                        No
# 3            Moderate       Moderate           Poor                        No
# 4                 Low       Moderate           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
# 2                         No                          Yes
# 3                         No                           No
# 4                         No                          Yes
#
#   Chronic Medical Conditions
# 0                        Yes
# 1                        Yes
# 2                         No
# 3                         No
# 4                        Yes

# %%
df["Employed"] = (df["Employment Status"] == "Employed").astype(np.int8)
df.drop("Employment Status", axis=1, inplace=True)

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#    Smoking Status  Physical Activity Level     Income Alcohol Consumption  \
# 0               0                        2   26265.67            Moderate
# 1               0                        0   42710.36                High
# 2               0                        0  125332.79                 Low
# 3               0                        1    9992.78            Moderate
# 4               0                        0    8595.08                 Low
#
#   Dietary Habits Sleep Patterns History of Mental Illness  \
# 0       Moderate           Fair                       Yes
# 1      Unhealthy           Fair                       Yes
# 2      Unhealthy           Good                        No
# 3       Moderate           Poor                        No
# 4       Moderate           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
# 2                         No                          Yes
# 3                         No                           No
# 4                         No                          Yes
#
#   Chronic Medical Conditions  Employed
# 0                        Yes         0
# 1                        Yes         1
# 2                         No         1
# 3                         No         0
# 4                        Yes         0

# %%
df["Alcohol Consumption"] = np.where(
    df["Alcohol Consumption"] == "Low", 0,
    np.where(df["Alcohol Consumption"] == "Moderate", 1,
             2
            )
    )

# %%
df.head(10)
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               3                2
# 1     Jacqueline Lewis   55               3                0
# 2       Shannon Church   78               3                3
# 3       Charles Jordan   58               0                3
# 4         Michael Rich   18               2                0
# 5           Kathy Hill   20               2                0
# 6      Crystal Delgado   60               3                4
# 7       Charles Kaiser   31               2                0
# 8       Kathryn Taylor   50               0                2
# 9  Alexander Hernandez   77               3                2
#
#    Number of Children  Smoking Status  Physical Activity Level     Income  \
# 0                   2               0                        2   26265.67
# 1                   1               0                        0   42710.36
# 2                   1               0                        0  125332.79
# 3                   3               0                        1    9992.78
# 4                   0               0                        0    8595.08
# 5                   0               1                        2   44448.91
# 6                   1               0                        0   22565.47
# 7                   0               0                        2   39608.18
# 8                   0               0                        2   93360.07
# 9                   2               0                        0   77597.84
#
#    Alcohol Consumption Dietary Habits Sleep Patterns  \
# 0                    1       Moderate           Fair
# 1                    2      Unhealthy           Fair
# 2                    0      Unhealthy           Good
# 3                    1       Moderate           Poor
# 4                    0       Moderate           Fair
# 5                    0      Unhealthy           Fair
# 6                    1       Moderate           Poor
# 7                    1      Unhealthy           Good
# 8                    1        Healthy           Good
# 9                    0      Unhealthy           Poor
#
#   History of Mental Illness History of Substance Abuse  \
# 0                       Yes                         No
# 1                       Yes                         No
# 2                        No                         No
# 3                        No                         No
# 4                       Yes                         No
# 5                        No                        Yes
# 6                        No                        Yes
# 7                        No                         No
# 8                        No                        Yes
# 9                       Yes                         No
#
#   Family History of Depression Chronic Medical Conditions  Employed
# 0                          Yes                        Yes         0
# 1                           No                        Yes         1
# 2                          Yes                         No         1
# 3                           No                         No         0
# 4                          Yes                        Yes         0
# 5                           No                         No         1
# 6                           No                         No         0
# 7                           No                         No         1
# 8                           No                        Yes         1
# 9                           No                         No         1

# %%
df["Dietary Habits"].value_counts()
# Out:
# Dietary Habits
# Unhealthy    170817
# Moderate     170446
# Healthy       72505
# Name: count, dtype: int64

# %%
df["Dietary Habits"] = np.where(
    df["Dietary Habits"] == "Unhealthy", 0,
    np.where(df["Dietary Habits"] == "Moderate", 1,
             2
            )
    )

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#    Smoking Status  Physical Activity Level     Income  Alcohol Consumption  \
# 0               0                        2   26265.67                    1
# 1               0                        0   42710.36                    2
# 2               0                        0  125332.79                    0
# 3               0                        1    9992.78                    1
# 4               0                        0    8595.08                    0
#
#    Dietary Habits Sleep Patterns History of Mental Illness  \
# 0               1           Fair                       Yes
# 1               0           Fair                       Yes
# 2               0           Good                        No
# 3               1           Poor                        No
# 4               1           Fair                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
# 2                         No                          Yes
# 3                         No                           No
# 4                         No                          Yes
#
#   Chronic Medical Conditions  Employed
# 0                        Yes         0
# 1                        Yes         1
# 2                         No         1
# 3                         No         0
# 4                        Yes         0

# %%
df["Sleep Patterns"].value_counts()
# Out:
# Sleep Patterns
# Fair    196789
# Poor    129582
# Good     87397
# Name: count, dtype: int64

# %%
df["Sleep Patterns"] = np.where(
    df["Sleep Patterns"] == "Poor", 0,
    np.where(df["Sleep Patterns"] == "Fair", 1,
            2
            )
    )

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#    Smoking Status  Physical Activity Level     Income  Alcohol Consumption  \
# 0               0                        2   26265.67                    1
# 1               0                        0   42710.36                    2
# 2               0                        0  125332.79                    0
# 3               0                        1    9992.78                    1
# 4               0                        0    8595.08                    0
#
#    Dietary Habits  Sleep Patterns History of Mental Illness  \
# 0               1               1                       Yes
# 1               0               1                       Yes
# 2               0               2                        No
# 3               1               0                        No
# 4               1               1                       Yes
#
#   History of Substance Abuse Family History of Depression  \
# 0                         No                          Yes
# 1                         No                           No
# 2                         No                          Yes
# 3                         No                           No
# 4                         No                          Yes
#
#   Chronic Medical Conditions  Employed
# 0                        Yes         0
# 1                        Yes         1
# 2                         No         1
# 3                         No         0
# 4                        Yes         0

# %%
for colname in ["History of Mental Illness", "History of Substance Abuse", "Family History of Depression", "Chronic Medical Conditions"]:
    df[colname] = (df[colname] == "Yes").astype(np.int8)

# %%
df.head()
# Out:
#                Name  Age  Marital Status  Education Level  Number of Children  \
# 0  Christine Barker   31               3                2                   2
# 1  Jacqueline Lewis   55               3                0                   1
# 2    Shannon Church   78               3                3                   1
# 3    Charles Jordan   58               0                3                   3
# 4      Michael Rich   18               2                0                   0
#
#    Smoking Status  Physical Activity Level     Income  Alcohol Consumption  \
# 0               0                        2   26265.67                    1
# 1               0                        0   42710.36                    2
# 2               0                        0  125332.79                    0
# 3               0                        1    9992.78                    1
# 4               0                        0    8595.08                    0
#
#    Dietary Habits  Sleep Patterns  History of Mental Illness  \
# 0               1               1                          1
# 1               0               1                          1
# 2               0               2                          0
# 3               1               0                          0
# 4               1               1                          1
#
#    History of Substance Abuse  Family History of Depression  \
# 0                           0                             1
# 1                           0                             0
# 2                           0                             1
# 3                           0                             0
# 4                           0                             1
#
#    Chronic Medical Conditions  Employed
# 0                           1         0
# 1                           1         1
# 2                           0         1
# 3                           0         0
# 4                           1         0

# %%
def pipeline(df):
    df.drop("Name", axis=1, inplace=True)

    
    df["Marital Status"] = np.where(
        df["Marital Status"] == "Divorced", 0,
        np.where(df["Marital Status"] == "Divorced", 1, 
                np.where(df["Marital Status"] == "Single", 2, 3
                        )
                )
    )

    df["Education Level"] = np.where(
        df["Education Level"] == "High School", 0,
        np.where(df["Education Level"] == "Accociate Degree", 1, 
                 np.where(df["Education Level"] == "Bachelor's Degree", 2,
                          np.where(df["Education Level"] == "Master's Degree", 3,
                                   4
                                  )
                         )
                )
    )

    df["Smoking Status"] = np.where(
        df["Smoking Status"] == "Non-smoker", 0,
            np.where(df["Smoking Status"] == "Former", 1,
                    2
            )
    )

    df["Physical Activity Level"] = np.where(
        df["Physical Activity Level"] == "Sedentary", 0, 
        np.where(df["Physical Activity Level"] == "Moderate", 1,
                2
            )
        )

    df["Employed"] = (df["Employment Status"] == "Employed").astype(np.int8)
    df.drop("Employment Status", axis=1, inplace=True)

    df["Alcohol Consumption"] = np.where(
        df["Alcohol Consumption"] == "Low", 0,
        np.where(df["Alcohol Consumption"] == "Moderate", 1,
                 2
                )
        )

    df["Dietary Habits"] = np.where(
        df["Dietary Habits"] == "Unhealthy", 0,
        np.where(df["Dietary Habits"] == "Moderate", 1,
                 2
                )
        )

    df["Sleep Patterns"] = np.where(
        df["Sleep Patterns"] == "Poor", 0,
        np.where(df["Sleep Patterns"] == "Fair", 1,
                2
                )
        )

    for colname in ["History of Mental Illness", "History of Substance Abuse", "Family History of Depression", "Chronic Medical Conditions"]:
        df[colname] = (df[colname] == "Yes").astype(np.int8)

    return df

# %%
df.drop("Name", axis=1, inplace=True)

# %%
x = pipeline(pd.read_csv("depression_data.csv"))

# %%
(x == df).to_numpy().all()
# Out:
# True

# %%
x[(x == df).to_numpy().sum(axis=1) < 15]
# Out:
# Empty DataFrame
# Columns: [Age, Marital Status, Education Level, Number of Children, Smoking Status, Physical Activity Level, Income, Alcohol Consumption, Dietary Habits, Sleep Patterns, History of Mental Illness, History of Substance Abuse, Family History of Depression, Chronic Medical Conditions, Employed]
# Index: []

# %%
import toolkit

# %%
x = toolkit.pipeline(pd.read_csv("depression_data.csv"))

# %%
(x == df).to_numpy().all()
# Out:
# True
