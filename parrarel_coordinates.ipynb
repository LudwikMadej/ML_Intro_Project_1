# %%
import pandas as pd

# %%
from toolkit import pipeline

# %%
df = pipeline(pd.read_csv("depression_data.csv"))

# %%
df.head()
# Out:
#    Age  Marital Status  Education Level  Number of Children  Smoking Status  \
# 0   31               3                2                   2               0
# 1   55               3                0                   1               0
# 2   78               3                3                   1               0
# 3   58               0                3                   3               0
# 4   18               2                0                   0               0
#
#    Physical Activity Level     Income  Alcohol Consumption  Dietary Habits  \
# 0                        2   26265.67                    1               1
# 1                        0   42710.36                    2               0
# 2                        0  125332.79                    0               0
# 3                        1    9992.78                    1               1
# 4                        0    8595.08                    0               1
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df["Age"] = (df["Age"]-df["Age"].min())/(df["Age"].max()-df["Age"].min())*3

# %%
df["Income"] = (df["Income"]-df["Income"].min())/(df["Income"].max()-df["Income"].min())*3

# %%
plt.figure(figsize=(20, 20))
pd.plotting.parallel_coordinates(df[:1_000], "Chronic Medical Conditions", color=["red", "green"])
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (413768, 15)
